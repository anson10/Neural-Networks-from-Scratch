# %%
# NUMERICAL DIFFERENTIATION

'''
The plan i.
s to visualize the tangent lines and how they
change depending on where we calculate them.

We’ll make the graph of this function
more granular using Numpy’s arange() , allowing us to plot with smaller steps. The
np.arange() function takes in start, stop, and step parameters, allowing us to take fractions of a
step, such as 0.001 at a time
'''

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return 2*x**2

# %%
x = np.arange(0,5,0.001)  #(start, stop, step)
y = f(x)

# %%
#plot the graph

plt.plot(x,y)
plt.show()

# %%
# NOW prepare tangent lines

'''
The function for a straight line is y = mx + b.
m-> slope or approximate_derivative
b-> y-intercept

To calculate b,
b = y - mx
'''

# %%
# Putting everything together
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 2*x**2

x = np.arange(0,5,0.001)  #(start, stop, step)
y = f(x)


plt.plot(x,y)

colors = ['k', 'g', 'r', 'b', 'c']

def approximate_tangent_line(x, derivative_approximation):
    return (derivative_approximation*x) + b
    
for i in range(5):
    p2_delta = 0.0001
    x1 = i
    x2 = x1 + p2_delta
    
    y1 = f(x1)
    y2 = f(x2)
    
    print((x1, y1), (x2, y2))
    
    #Derivative aproximation
    derivative_approximation = (y2-y1)/(x2-x1)
    b = y2 - derivative_approximation*x2
    
    def tanget_line(x):
        return derivative_approximation*x + b
    
    to_plot = [x1-0.9, x1, x1+0.9]
    
    plt.scatter(x1, y1, c=colors[i])
    plt.plot([point for point in to_plot],
            [approximate_tangent_line(point, derivative_approximation)
            for point in to_plot], c=colors[i])
    plt.plot(to_plot, [tanget_line(i) for i in to_plot])
    
    print('Approximate Derivative for f(x)',
         f'wherr x = {x1} is {derivative_approximation}')
plt.show()
# Out:
# (0, 0) (0.0001, 2e-08)
# Approximate Derivative for f(x) wherr x = 0 is 0.00019999999999999998
# (1, 2) (1.0001, 2.00040002)
# Approximate Derivative for f(x) wherr x = 1 is 4.0001999999987845
# (2, 8) (2.0001, 8.000800020000002)
# Approximate Derivative for f(x) wherr x = 2 is 8.000199999998785
# (3, 18) (3.0001, 18.001200020000002)
# Approximate Derivative for f(x) wherr x = 3 is 12.000199999998785
# (4, 32) (4.0001, 32.00160002)
# Approximate Derivative for f(x) wherr x = 4 is 16.000200000016548
